# %%
import pandas as pd
from rdkit.Chem import AllChem, Draw, PandasTools
from rdkit.Chem.Draw import IPythonConsole
import sascorer
# %matplotlib inline

# %%
df = pd.read_csv("/Users/lpc_0066/Desktop/Dataset/その他/Volume of Distribution/VDss_dataset_uen.csv", index_col=0)

# %%
df
# Out:
#                                                  SMILES       MW     logP  \
# 0               CC(C)N(CCC(c1ccccc1)c1cc(CO)ccc1O)C(C)C  341.495  4.52530
# 1     O=C(OC1C[N+]2(CCCOc3ccccc3)CCC1CC2)C(O)(c1cccs...  484.663  4.66680
# 2     CC[C@H]1C2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]45C[C@...  326.440  1.55450
# 3     C=CC[N+]12CCC34c5ccccc5N5/C=C6/C7CC8C9(CC[N+]8...  666.910  5.47560
# 4                  CCCS(=O)CCCN(CC)CC(O)COc1ccc(C#N)cc1  352.500  2.16868
# ...                                                 ...      ...      ...
# 2435  C[C@@H](O)[C@H]1C(=O)N2C(C(=O)O)=C(S[C@@H]3CN[...  420.513 -1.60310
# 2436  CCCCC[C@H](O)CC[C@@H]1[C@H]2Cc3cccc(OCC(=O)O)c...  390.520  3.58320
# 2437  Cn1c(N)c(NC(=O)NCCN)c[n+]1CC1=C(C(=O)O)N2C(=O)...  667.711 -2.56860
# 2438  CCCSc1nc(N[C@@H]2C[C@H]2c2ccc(F)c(F)c2)c2nnn([...  522.578  2.01370
# 2439  CCOc1ccc(Cc2cc([C@@H]3O[C@H](CO)[C@@H](O)[C@H]...  408.878  1.84440
#
#       VDss(L/kg)   logVDss
# 0       2.410000  0.382017
# 1       4.300000  0.633468
# 2       4.000000  0.602060
# 3       0.320000 -0.494850
# 4       1.800000  0.255273
# ...          ...       ...
# 2435    0.229087 -0.640000
# 2436    0.229087 -0.640000
# 2437    0.169824 -0.770000
# 2438    1.258925  0.100000
# 2439    1.698244  0.230000
#
# [2440 rows x 5 columns]

# %%
PandasTools.AddMoleculeColumnToFrame(frame=df, smilesCol='SMILES')
df.head(3)
# Out:
#                                               SMILES       MW    logP  \
# 0            CC(C)N(CCC(c1ccccc1)c1cc(CO)ccc1O)C(C)C  341.495  4.5253
# 1  O=C(OC1C[N+]2(CCCOc3ccccc3)CCC1CC2)C(O)(c1cccs...  484.663  4.6668
# 2  CC[C@H]1C2C[C@H]3[C@@H]4N(C)c5ccccc5[C@]45C[C@...  326.440  1.5545
#
#    VDss(L/kg)   logVDss                                          ROMol
# 0        2.41  0.382017  <rdkit.Chem.rdchem.Mol object at 0x168a5e180>
# 1        4.30  0.633468  <rdkit.Chem.rdchem.Mol object at 0x168a5d1c0>
# 2        4.00  0.602060  <rdkit.Chem.rdchem.Mol object at 0x168a5dc40>
