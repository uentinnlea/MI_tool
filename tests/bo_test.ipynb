# %%
import sys
import os

# Add the project root to PYTHONPATH
sys.path.append(os.path.abspath("../"))


import pandas as pd
from inverse_analysis.bayesian_opt.gaussian_process import GaussianProcessRegressor

# %%
df = pd.read_excel("./data/diabetes_dataset.xlsx")

# %%
df
# Out:
#            s1        s2        s3        s4        s5        s6       bmi  \
# 0   -0.044223 -0.034821 -0.043401 -0.002592  0.019907 -0.017646  0.061696
# 1   -0.008449 -0.019163  0.074412 -0.039493 -0.068332 -0.092204 -0.051474
# 2   -0.045599 -0.034194 -0.032356 -0.002592  0.002861 -0.025930  0.044451
# 3    0.012191  0.024991 -0.036038  0.034309  0.022688 -0.009362 -0.011595
# 4    0.003935  0.015596  0.008142 -0.002592 -0.031988 -0.046641 -0.036385
# ..        ...       ...       ...       ...       ...       ...       ...
# 437 -0.005697 -0.002566 -0.028674 -0.002592  0.031193  0.007207  0.019662
# 438  0.049341  0.079165 -0.028674  0.034309 -0.018114  0.044485 -0.015906
# 439 -0.037344 -0.013840 -0.024993 -0.011080 -0.046883  0.015491 -0.015906
# 440  0.016318  0.015283 -0.028674  0.026560  0.044529 -0.025930  0.039062
# 441  0.083740  0.027809  0.173816 -0.039493 -0.004222  0.003064 -0.073030
#
#            bp       age       sex  target
# ...
